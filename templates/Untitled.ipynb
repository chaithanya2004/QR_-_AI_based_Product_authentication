# %%
<!DOCTYPE html>
<html>
<head>
    <title>Waste Reduction AI</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='css/style.css') }}">
    <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/css/bootstrap.min.css" rel="stylesheet">
</head>
<body>
<div class="container mt-5">
    <h1>Waste Reduction AI Dashboard</h1>
    <form method="POST">
        <button type="submit" class="btn btn-primary mb-3">Predict Unsold Items</button>
    </form>
    
    {% if predictions %}
    <table class="table table-bordered">
        <thead>
            <tr>
                <th>Item Name</th>
                <th>Stock Quantity</th>
                <th>Predicted Unsold</th>
                <th>Suggested Action</th>
            </tr>
        </thead>
        <tbody>
            {% for row in predictions %}
            <tr>
                <td>{{ row['Item_Name'] }}</td>
                <td>{{ row['Stock_Quantity'] }}</td>
                <td>{{ row['Predicted_Unsold'] | round(2) }}</td>
                <td>{{ row['Action'] }}</td>
            </tr>
            {% endfor %}
        </tbody>
    </table>
    {% endif %}
</div>
</body>
</html>
